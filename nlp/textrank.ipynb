# %%
import numpy as np

# %%
A = np.array([[0.2, 0.8], [0.4, 0.6]])
s_t = np.array([1,1])

# %%
temp = s_t @ A
for i in range(10):
  print(temp)
  temp = temp @ A
# Out:
# [0.6 1.4]
# [0.68 1.32]
# [0.664 1.336]
# [0.6672 1.3328]
# [0.66656 1.33344]
# [0.666688 1.333312]
# [0.6666624 1.3333376]
# [0.66666752 1.33333248]
# [0.6666665 1.3333335]
# [0.6666667 1.3333333]

# %%
# Out:
# array([7.91319734, 8.07678418])
